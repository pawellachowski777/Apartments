# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

from scipy import stats
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

from sklearn.neighbors import LocalOutlierFactor

from sklearn import metrics
import statsmodels.api as sm 
from statsmodels.formula.api import ols

# %%
df_waw = pd.read_excel('excel_reg_update.xlsx')
df_waw
# Out:
#            dzielnica                 od  poziom  umeblowanie         zabudowa  \
# 0            Wilanów    Osoby prywatnej  Parter            1  Apartamentowiec
# 1        Śródmieście    Osoby prywatnej       1            1  Apartamentowiec
# 2        Śródmieście    Osoby prywatnej       4            0             Blok
# 3       Praga-Północ    Osoby prywatnej  Parter            0        Kamienica
# 4            Wilanów    Osoby prywatnej       3            1             Blok
# ...              ...                ...     ...          ...              ...
# 1691       Białołęka    Osoby prywatnej       3            1             Blok
# 1692         Bielany  Biuro / Deweloper       1            1        Kamienica
# 1693        Żoliborz    Osoby prywatnej       5            1             Blok
# 1694         Mokotów  Biuro / Deweloper       2            1        Kamienica
# 1695  Praga-Południe    Osoby prywatnej       1            1             Blok
#
#       powierzchnia  pokoje  cena calkowita  cena za pokoj
# 0               80       3           10470    3490.000000
# 1              137       4            5801    1450.250000
# 2               84       3            6400    2133.333333
# 3               94       4            5401    1350.250000
# 4              100       3            4501    1500.333333
# ...            ...     ...             ...            ...
# 1691            40       2            1701     850.500000
# 1692            47       2            2370    1185.000000
# 1693            37       2            2200    1100.000000
# 1694            53       3            2801     933.666667
# 1695            35       1            1501    1501.000000
#
# [1696 rows x 9 columns]

# %%
# # wszystkie modyfikacje 
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
# sns.set()
# from scipy import stats
# df_waw = pd.read_excel('excel2.xlsx')

# def drop_value(df, column, value): # funkcja do usuwania wybranych wartości
#     index = df[df[column] == value].index
#     df.drop(index=index, inplace=True)
#     df.reset_index(drop=True, inplace=True)

# index = df_waw[df_waw['pokoje'] == 'Kawalerka'].index
# for i in index:
#     df_waw.loc[i, 'pokoje'] = 1   
# df_waw['pokoje'] = df_waw['pokoje'].astype(int)

# drop_value(df_waw, 'poziom', 'Tak')
# drop_value(df_waw, 'poziom', 'Nie')

# df_waw.drop_duplicates(inplace=True)
# df_waw.drop(['link', 'miasto'], axis=1, inplace=True)

# df_waw['cena całkowita'] = df_waw['cena'] + df_waw['czynsz dodatkowo']
# df_waw.drop('cena', axis=1, inplace=True)
# df_waw.drop('czynsz dodatkowo', axis=1, inplace=True)
# df_waw.reset_index(drop=True, inplace=True)

# drop_value(df_waw, 'cena całkowita', df_waw['cena całkowita'].max())
# drop_value(df_waw, 'powierzchnia', df_waw['powierzchnia'].max())

# drop_value(df_waw, 'zabudowa', 'Loft')
# drop_value(df_waw, 'zabudowa', 'Pozostałe')

# drop_value(df_waw, 'poziom', 'Suterena')
# drop_value(df_waw, 'poziom', 'Poddasze')

# %% [markdown]
# # Zwykła

# %% [markdown]
# ## Multicollinearity

# %% [markdown]
# Problemy z współliniowością zmienneych objaśniających:
# Gdy dwie zmienne są ze sobą skorelowane, model nie wie, czy wzrost pierwszej czy drugiej zmiennej wpłyną na wynik.
# Interpretując coefficient zmiennej, przyjmuje się, że jej wzrost o jedną jedostkę powoduję wzrost wyniku o wartość coeff, przy założeniu, że pozostałe zmienne są stałe. Gdy dwie zmienne są skorelowane, wzrost jednej oznacza wzrost drugiej.
#
# Współlinniowość wływa na odhylenie standardowe, t stat i p_value zmiennych

# %%
plt.figure(figsize=(15,10))
sns.heatmap(X.corr(), cmap='coolwarm')

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif_data = pd.DataFrame()
vif_data["feature"] = X.columns 

vif_data["VIF"] = [variance_inflation_factor(X.values, i) 
                          for i in range(len(X.columns))] 

print(vif_data)

# %%
print('''Badanie normalności składników resztowych
H_0 - występuje rokład normalny
H_1 - brak rozkładu normalnego
a = 0.05
''')

stat, p = stats.shapiro(residuals)
print('p value: %.10f, \n'%(p))

if p > 0.05:
    print('Nie ma podstaw do odrzucenia hipotezy zerowej. Występuje rozkład normalny.')
else:
    print('Odrzucamy hipotezę zerową na rzecz hipotezy alternatywnej. Brak rozkładu normalnego.')

sns.distplot(residuals)
plt.show()
# Out:
# Badanie normalności składników resztowych
# H_0 - występuje rokład normalny
# H_1 - brak rozkładu normalnego
# a = 0.05
#
# p value: 0.0000000000,
#
# Odrzucamy hipotezę zerową na rzecz hipotezy alternatywnej. Brak rozkładu normalnego.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

from scipy import stats
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

import statsmodels.api as sm
from statsmodels.formula.api import ols
import statsmodels.stats.api as sms

# %%
drop_value(df_waw, 'powierzchnia', 1)

# %%
# wszystkie modyfikacje 

df_waw = pd.read_excel('web_scrap.xlsx')

def drop_value(df, column, value): # funkcja do usuwania wybranych wartości
    index = df[df[column] == value].index
    df.drop(index=index, inplace=True)
    df.reset_index(drop=True, inplace=True)

index = df_waw[df_waw['pokoje'] == 'Kawalerka'].index
for i in index:
    df_waw.loc[i, 'pokoje'] = 1   
df_waw['pokoje'] = df_waw['pokoje'].astype(int)

drop_value(df_waw, 'poziom', 'Tak')
drop_value(df_waw, 'poziom', 'Nie')

df_waw.drop_duplicates(inplace=True)
df_waw.drop(['link', 'miasto'], axis=1, inplace=True)

df_waw['cena całkowita'] = df_waw['cena'] + df_waw['czynsz dodatkowo']
df_waw.drop('cena', axis=1, inplace=True)
df_waw.drop('czynsz dodatkowo', axis=1, inplace=True)
df_waw.reset_index(drop=True, inplace=True)

drop_value(df_waw, 'cena całkowita', df_waw['cena całkowita'].max())
drop_value(df_waw, 'powierzchnia', df_waw['powierzchnia'].max())

drop_value(df_waw, 'zabudowa', 'Loft')
drop_value(df_waw, 'zabudowa', 'Pozostałe')

drop_value(df_waw, 'poziom', 'Suterena')
drop_value(df_waw, 'poziom', 'Poddasze')

#df_waw['powierzchnia na pokój'] = df_waw['powierzchnia'] / df_waw['pokoje'] # dodam kolumne powierzchnia na pokój, żeby nie marnować danych z pokoju
df_waw['cena za pokój'] = df_waw['cena całkowita'] / df_waw['pokoje']
df_waw['powierzchnia kw'] = 1/df_waw['powierzchnia']

dzielnica = pd.get_dummies(data=df_waw['dzielnica'])
od = pd.get_dummies(data=df_waw['od'])
poziom = pd.get_dummies(data=df_waw['poziom'])
zabudowa = pd.get_dummies(data=df_waw['zabudowa'])

df_waw = pd.concat([df_waw, dzielnica, od, poziom, zabudowa], axis=1)

y = df_waw['cena za pokój']
X = df_waw.drop(['cena całkowita', 'dzielnica', 'od', 'poziom', 'zabudowa', 'umeblowanie', 'cena za pokój',
                 'Mokotów', 'Osoby prywatnej', 'Powyżej 10', 'Apartamentowiec'], axis=1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=60)

# %%
lm = LinearRegression()
lm.fit(X_train, y_train)
prediction = lm.predict(X_test) 
residuals = prediction - y_test # składniki resztowe

# %%
X_const = sm.add_constant(X_train)
ols = sm.OLS(y_train, X_const)
results = ols.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          cena za pokój   R-squared:                       0.568
# Model:                            OLS   Adj. R-squared:                  0.563
# Method:                 Least Squares   F-statistic:                     102.6
# Date:                Sun, 22 Nov 2020   Prob (F-statistic):               0.00
# Time:                        15:57:31   Log-Likelihood:                -20378.
# No. Observations:                2844   AIC:                         4.083e+04
# Df Residuals:                    2807   BIC:                         4.105e+04
# Df Model:                          36
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const              2113.1830     46.350     45.592      0.000    2022.299    2204.067
# powierzchnia         15.1982      0.662     22.957      0.000      13.900      16.496
# pokoje             -654.3586     13.377    -48.918      0.000    -680.588    -628.130
# powierzchnia kw    1939.4939    313.925      6.178      0.000    1323.947    2555.041
# Bemowo             -133.5088     30.002     -4.450      0.000    -192.337     -74.681
# Białołęka          -165.3127     29.890     -5.531      0.000    -223.922    -106.703
# Bielany            -145.7087     30.367     -4.798      0.000    -205.252     -86.165
# Ochota              -38.0259     28.988     -1.312      0.190     -94.867      18.815
# Praga-Południe      -98.0604     24.516     -4.000      0.000    -146.132     -49.989
# Praga-Północ        -26.5208     38.404     -0.691      0.490    -101.823      48.782
# Rembertów          -130.9298     87.624     -1.494      0.135    -302.744      40.885
# Targówek           -172.0643     33.285     -5.169      0.000    -237.331    -106.798
# Ursus              -125.0156     40.406     -3.094      0.002    -204.244     -45.787
# Ursynów             -34.4487     29.044     -1.186      0.236     -91.398      22.501
# Wawer              -217.9434     57.939     -3.762      0.000    -331.551    -104.336
# Wesoła             -196.4029     76.595     -2.564      0.010    -346.592     -46.214
# Wilanów             -51.5152     46.711     -1.103      0.270    -143.107      40.077
# Wola                 24.3668     22.474      1.084      0.278     -19.701      68.434
# Włochy             -113.0666     38.787     -2.915      0.004    -189.121     -37.012
# Śródmieście          20.9291     21.841      0.958      0.338     -21.896      63.755
# Żoliborz             -5.8990     36.461     -0.162      0.871     -77.392      65.594
# Biuro / Deweloper   -64.0955     15.036     -4.263      0.000     -93.579     -34.613
# 1                  -100.7953     38.713     -2.604      0.009    -176.703     -24.887
# 10                  -41.3361     50.729     -0.815      0.415    -140.805      58.133
# 2                   -98.4251     38.849     -2.534      0.011    -174.601     -22.250
# 3                   -64.4619     39.082     -1.649      0.099    -141.094      12.170
# 4                   -20.4179     40.229     -0.508      0.612     -99.299      58.464
# 5                   -20.8914     42.048     -0.497      0.619    -103.340      61.557
# 6                   -42.2418     43.624     -0.968      0.333    -127.779      43.296
# 7                   -43.3593     48.397     -0.896      0.370    -138.257      51.539
# 8                   -77.4095     50.596     -1.530      0.126    -176.618      21.799
# 9                   -77.2754     55.203     -1.400      0.162    -185.518      30.967
# Parter              -87.8947     40.122     -2.191      0.029    -166.566      -9.223
# Blok               -138.4799     15.709     -8.815      0.000    -169.283    -107.677
# Dom                -387.9968     47.454     -8.176      0.000    -481.046    -294.948
# Kamienica           -88.4231     20.867     -4.237      0.000    -129.339     -47.507
# Szeregowiec        -258.7979     91.468     -2.829      0.005    -438.148     -79.447
# ==============================================================================
# Omnibus:                      484.483   Durbin-Watson:                   2.003
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7835.283
# Skew:                           0.286   Prob(JB):                         0.00
# Kurtosis:                      11.111   Cond. No.                     2.41e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.41e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
plt.scatter(df_waw['cena za pokój'], df_waw['powierzchnia kw'])

# %%
plt.figure(figsize = (12,8))
plt.xlabel('Predykcja')
plt.ylabel('Cena faktyczna')
plt.title('Cena faktyczna vs predykcja', fontdict={'fontsize':15})
sns.regplot(prediction, y_test)
plt.show()

# %%
import pickle 
with open('linear_model.pickle', 'wb') as writer:
    pickle.dump([lm, X_test], writer)

# %%
import pickle 
with open('linear_model.pickle', 'rb') as reader:
    lm, X_test = pickle.load(reader)

# %%
columns = list(X_test.columns)

# %%
list_district = columns[1:18] # brak Mokotów

# %%
print(list_level)
# Out:
# ['1', '10', '2', '3', '4', '5', '6', '7', '8', '9', 'Parter']

# %%
list_by = columns[18] # bez osoby prywatnej

# %%
list_level = columns[19:30] # brak powyżej 10

# %%
list_building = columns[30:] # brak apartamentowiec

# %%
df_waw.zabudowa.unique()
# Out:
# array(['Apartamentowiec', 'Blok', 'Kamienica', 'Dom', 'Szeregowiec'],
#       dtype=object)

# %%
def price_predict(surfance, district, by, level, building):
    """
    district: 'Bemowo', 'Białołęka', 'Bielany', 'Ochota', 'Praga-Południe', 'Praga-Północ', 
              'Rembertów', 'Targówek', 'Ursus', 'Ursynów', 'Wawer', 'Wesoła', 'Wilanów', 'Wola', 
              'Włochy', 'Śródmieście', 'Żoliborz', 'Mokotów',
    by: 'Biuro / Deweloper', 'Osoby prywatnej',
    level: '1', '10', '2', '3', '4', '5', '6', '7', '8', '9', 'Parter', 'Powyżej 10',
    building: 'Blok', 'Kamienica', 'Dom', 'Szeregowiec', 'Apartamentowiec',
    """
    
    import numpy as np
    
    columns = list(X_test.columns)
    list_district = columns[1:18] # brak Mokotów
    list_level = columns[19:30] # brak powyżej 10
    list_building = columns[30:] # brak apartamentowiec
    values = np.array(surfance)
    
    for dist in list_district:
        if dist == district:
            values = np.append(values, 1)
        else:
            values = np.append(values, 0)

    if by == 'Biuro / Deweloper':
        values = np.append(values, 1)
    else:
        values = np.append(values, 0)

    for lv in list_level:
        if lv == level:
            values = np.append(values, 1)
        else:
            values = np.append(values, 0)
            
    for build in list_building:
        if build == building:
            values = np.append(values, 1)
        else:
            values = np.append(values, 0)
    
    values = values.reshape(1,-1)
    predict = lm.predict(values)
    print(f'Przewidywana cena to {round(predict[0],2)} zł.')
    return predict

# %%
val = price_predict(38, 'Mokotów', 'Biuro / Deweloper', '1', 'Blok')
# Out:
# Przewidywana cena to 2089.94 zł.

# %%
# Out:
# array([2089.93685926])

# %%
print(val.shape)
print(X_test[:1].values.shape)
# Out:
# (1, 34)
# (1, 34)

# %%
lm.predict(val)
# Out:
# array([2089.93685926])
